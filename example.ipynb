# %%
import numpy as np
import torch
from core.enhanced_input_classifier_demo import demonstrate_enhanced_classification, demonstrate_glove_semantic_analysis, \
    analyze_classifier_performance, create_comprehensive_visualization, demonstrate_online_learning, \
        run_comprehensive_evaluation
from mmi import demonstrate_multi_model_inference, analyze_results, save_results

# %%
"""Main demonstration function"""
    
print("🚀 Complete Enhanced Input Classifier Demo")
print("🔥 TF-IDF + GloVe + Manifold Learning Integration")
print("=" * 65)
print("Features demonstrated:")
print("• Traditional pattern-based classification")
print("• TF-IDF vectorization for lexical features")
print("• GloVe embeddings for semantic understanding")
print("• Manifold learning with geometric spaces")
print("• Uncertainty quantification and confidence scoring")
print("• Semantic coherence analysis")
print("• Online learning and performance feedback")
print("• Multi-modal feature fusion")
print("• Comprehensive performance analysis")
print("=" * 65)

try:
    # Step 1: Enhanced classification demonstration
    print("\n🎯 Step 1: Enhanced Classification with Multi-Modal Features")
    results, classifier = demonstrate_enhanced_classification()
    
    # Step 2: GloVe semantic analysis
    print("\n🎯 Step 2: GloVe Semantic Analysis")
    demonstrate_glove_semantic_analysis(classifier)
    
    # Step 3: Performance analysis
    print("\n🎯 Step 3: Performance Analysis")
    analyze_classifier_performance(results, classifier)
    
    # Step 4: Comprehensive visualization
    print("\n🎯 Step 4: Comprehensive Visualization")
    create_comprehensive_visualization(results)
    
    # Step 5: Online learning demonstration
    print("\n🎯 Step 5: Online Learning and Adaptation")
    demonstrate_online_learning(classifier)
    
    # Step 6: Comprehensive evaluation
    print("\n🎯 Step 6: Comprehensive Evaluation")
    run_comprehensive_evaluation(classifier, results)
    
    # Final summary and insights
    print(f"\n🎉 Complete Enhanced Classifier Demo Finished!")
    print("=" * 55)
    print("✅ Demonstrated multi-modal feature fusion (TF-IDF + GloVe)")
    print("✅ Showed geometric manifold learning integration")
    print("✅ Analyzed semantic coherence and word relationships")
    print("✅ Visualized comprehensive performance metrics")
    print("✅ Demonstrated adaptive online learning")
    print("✅ Provided interpretable confidence and uncertainty scores")
    
    # Key insights and recommendations
    print(f"\n💡 Key Insights and Recommendations:")
    final_stats = classifier.get_classification_statistics()
    
    if final_stats.get('total_predictions', 0) > 0:
        print(f"   • Final classification accuracy: {final_stats['overall_accuracy']:.2%}")
    
    # Multi-modal feature insights
    avg_coherence = np.mean([r['glove_coherence'] for r in results])
    avg_embedding_strength = np.mean([r['glove_embedding_norm'] for r in results])
    avg_confidence = np.mean([r['confidence'] for r in results])
    avg_uncertainty = np.mean([r['uncertainty'] for r in results])
    
    print(f"   • Average semantic coherence: {avg_coherence:.3f}")
    print(f"   • Average classification confidence: {avg_confidence:.3f}")
    print(f"   • Average uncertainty estimate: {avg_uncertainty:.3f}")
    
    # Method comparison insights
    traditional_better = sum(1 for r in results 
                            if r.get('traditional_confidence', 0) > r.get('manifold_confidence', 0))
    manifold_better = sum(1 for r in results 
                        if r.get('manifold_confidence', 0) > r.get('traditional_confidence', 0))
    
    if traditional_better + manifold_better > 0:
        manifold_win_rate = manifold_better / (traditional_better + manifold_better)
        print(f"   • Enhanced method win rate: {manifold_win_rate:.1%}")
    
    print(f"   • Multi-modal approach provides richer semantic understanding")
    print(f"   • Online learning enables continuous improvement")
    print(f"   • Uncertainty quantification helps identify difficult cases")
    print(f"   • Geometric manifolds capture task-specific structures")
    
    # Usage recommendations
    print(f"\n🔧 Usage Recommendations:")
    print(f"   • Use GloVe embeddings for semantic similarity tasks")
    print(f"   • Monitor uncertainty scores for active learning")
    print(f"   • Apply different manifolds based on task characteristics")
    print(f"   • Leverage online learning for domain adaptation")
    print(f"   • Combine traditional and geometric features for robustness")

    
except Exception as e:
    print(f"❌ Demo failed: {e}")
    import traceback
    traceback.print_exc()
# Out:
# 🚀 Complete Enhanced Input Classifier Demo
# 🔥 TF-IDF + GloVe + Manifold Learning Integration
# =================================================================
# Features demonstrated:
# • Traditional pattern-based classification
# • TF-IDF vectorization for lexical features
# • GloVe embeddings for semantic understanding
# • Manifold learning with geometric spaces
# • Uncertainty quantification and confidence scoring
# • Semantic coherence analysis
# • Online learning and performance feedback
# • Multi-modal feature fusion
# • Comprehensive performance analysis
# =================================================================
#
# 🎯 Step 1: Enhanced Classification with Multi-Modal Features
# 🧠 Enhanced Input Classifier with TF-IDF + GloVe + Manifold Learning
# ======================================================================
# 🔧 Creating synthetic GloVe-like embeddings...
# ✅ Created 128 synthetic word vectors (dim=100)
# 🔧 Training classifier with 35 examples...
# 🔧 Fitting classifier on 35 training examples...
# 🌐 Training manifold learner...
# 🧠 Learning manifold from 35 offline samples...
# ✅ Manifold learning completed. Found 7 clusters.
# ✅ Manifold learner trained with 35 samples
# ✅ Classifier fitting complete!
#
# 🧪 Testing enhanced classifier with 12 cases...
# ======================================================================
#
# [1] Testing: Solve the differential equation dy/dx = 2x + 3...
#   📊 Task Type: mathematical
#   🎯 Confidence: 0.919
#   🔮 Uncertainty: 0.250
#   🌐 Best Manifold: euclidean
#   📈 Complexity: 0.189
#   🔑 Keywords: solve, differential, equation
#   🏷️ Domains: None
#   ⚡ Analysis Time: 0.0076s
#   🎭 GloVe Features:
#     Semantic Coherence: 0.094
#     Embedding Strength: 0.629
#     Math Similarity: 1.000
#     Creative Similarity: 0.110
#   🔄 Method Comparison:
#     Traditional: 1.000
#     Manifold: 0.750
#
# [2] Testing: Write a science fiction story about time travel...
#   📊 Task Type: creative_writing
#   🎯 Confidence: 0.704
#   🔮 Uncertainty: 0.400
#   🌐 Best Manifold: sphere
#   📈 Complexity: 0.089
#   🔑 Keywords: write, science, fiction
#   🏷️ Domains: creative
#   ⚡ Analysis Time: 0.0037s
#   🎭 GloVe Features:
#     Semantic Coherence: 0.059
#     Embedding Strength: 0.542
#     Math Similarity: 0.129
#     Creative Similarity: 1.000
#   🔄 Method Comparison:
#     Traditional: 0.750
#     Manifold: 0.600
#
# [3] Testing: Implement a graph traversal algorithm using DFS...
#   📊 Task Type: mathematical
#   🎯 Confidence: 0.978
#   🔮 Uncertainty: 0.300
#   🌐 Best Manifold: euclidean
#   📈 Complexity: 0.139
#   🔑 Keywords: implement, graph, traversal
#   🏷️ Domains: None
#   ⚡ Analysis Time: 0.0017s
#   🎭 GloVe Features:
#     Semantic Coherence: 0.188
#     Embedding Strength: 0.771
#     Math Similarity: 0.109
#     Creative Similarity: 0.155
#   🔄 Method Comparison:
#     Traditional: 1.000
#     Manifold: 0.700
#
# [4] Testing: Analyze the advantages and disadvantages of remote...
#   📊 Task Type: reasoning
#   🎯 Confidence: 0.776
#   🔮 Uncertainty: 0.350
#   🌐 Best Manifold: hyperbolic
#   📈 Complexity: 0.091
#   🔑 Keywords: analyze, advantages, disadvantages
#   🏷️ Domains: None
#   ⚡ Analysis Time: 0.0033s
#   🎭 GloVe Features:
#     Semantic Coherence: 0.021
#     Embedding Strength: 0.589
#     Math Similarity: 0.111
#     Creative Similarity: 0.221
#   🔄 Method Comparison:
#     Traditional: 1.000
#     Manifold: 0.650
#
# [5] Testing: Explain quantum entanglement and its applications...
#   📊 Task Type: conversational
#   🎯 Confidence: 0.544
#   🔮 Uncertainty: 0.500
#   🌐 Best Manifold: torus
#   📈 Complexity: 0.070
#   🔑 Keywords: explain, quantum, entanglement
#   🏷️ Domains: None
#   ⚡ Analysis Time: 0.0031s
#   🎭 GloVe Features:
#     Semantic Coherence: -0.106
#     Embedding Strength: 0.669
#     Math Similarity: 0.111
#     Creative Similarity: 0.221
#   🔄 Method Comparison:
#     Traditional: 1.000
#     Manifold: 0.500
#
# [6] Testing: What are the main causes of the American Civil War...
#   📊 Task Type: mathematical
#   🎯 Confidence: 0.920
#   🔮 Uncertainty: 0.400
#   🌐 Best Manifold: euclidean
#   📈 Complexity: 0.060
#   🔑 Keywords: main, causes, american
#   🏷️ Domains: None
#   ⚡ Analysis Time: 0.0036s
#   🎭 GloVe Features:
#     Semantic Coherence: 0.342
#     Embedding Strength: 0.712
#     Math Similarity: 0.100
#     Creative Similarity: 0.013
#   🔄 Method Comparison:
#     Traditional: 1.000
#     Manifold: 0.600
#
# [7] Testing: Hello! I hope you're having a wonderful day!...
#   📊 Task Type: conversational
#   🎯 Confidence: 0.755
#   🔮 Uncertainty: 0.350
#   🌐 Best Manifold: torus
#   📈 Complexity: 0.035
#   🔑 Keywords: hello, hope, having
#   🏷️ Domains: None
#   ⚡ Analysis Time: 0.0021s
#   🎭 GloVe Features:
#     Semantic Coherence: 0.000
#     Embedding Strength: 1.000
#     Math Similarity: 0.260
#     Creative Similarity: 0.147
#   🔄 Method Comparison:
#     Traditional: 1.000
#     Manifold: 0.650
#
# [8] Testing: How do neural networks learn patterns in data?...
#   📊 Task Type: mathematical
#   🎯 Confidence: 0.649
#   🔮 Uncertainty: 0.450
#   🌐 Best Manifold: euclidean
#   📈 Complexity: 0.049
#   🔑 Keywords: neural, networks, learn
#   🏷️ Domains: None
#   ⚡ Analysis Time: 0.0035s
#   🎭 GloVe Features:
#     Semantic Coherence: 0.050
#     Embedding Strength: 0.605
#     Math Similarity: 0.274
#     Creative Similarity: 0.049
#   🔄 Method Comparison:
#     Traditional: 0.714
#     Manifold: 0.550
#
# [9] Testing: Create an algorithm to optimize investment portfol...
#   📊 Task Type: mathematical
#   🎯 Confidence: 0.840
#   🔮 Uncertainty: 0.350
#   🌐 Best Manifold: euclidean
#   📈 Complexity: 0.141
#   🔑 Keywords: create, algorithm, optimize
#   🏷️ Domains: None
#   ⚡ Analysis Time: 0.0029s
#   🎭 GloVe Features:
#     Semantic Coherence: 0.085
#     Embedding Strength: 0.736
#     Math Similarity: 0.161
#     Creative Similarity: 0.155
#   🔄 Method Comparison:
#     Traditional: 1.000
#     Manifold: 0.650
#
# [10] Testing: What makes a compelling narrative structure?...
#   📊 Task Type: mathematical
#   🎯 Confidence: 0.489
#   🔮 Uncertainty: 0.450
#   🌐 Best Manifold: euclidean
#   📈 Complexity: 0.039
#   🔑 Keywords: makes, compelling, narrative
#   🏷️ Domains: None
#   ⚡ Analysis Time: 0.0028s
#   🎭 GloVe Features:
#     Semantic Coherence: -0.073
#     Embedding Strength: 0.681
#     Math Similarity: 0.180
#     Creative Similarity: 0.127
#   🔄 Method Comparison:
#     Traditional: 0.588
#     Manifold: 0.550
#
# [11] Testing: Calculate the ROI of a marketing campaign...
#   📊 Task Type: mathematical
#   🎯 Confidence: 0.675
#   🔮 Uncertainty: 0.400
#   🌐 Best Manifold: euclidean
#   📈 Complexity: 0.078
#   🔑 Keywords: calculate, marketing, campaign
#   🏷️ Domains: None
#   ⚡ Analysis Time: 0.0028s
#   🎭 GloVe Features:
#     Semantic Coherence: -0.045
#     Embedding Strength: 0.691
#     Math Similarity: 1.000
#     Creative Similarity: 0.081
#   🔄 Method Comparison:
#     Traditional: 1.000
#     Manifold: 0.600
#
# [12] Testing: Debug and explain this machine learning model...
#   📊 Task Type: conversational
#   🎯 Confidence: 0.357
#   🔮 Uncertainty: 0.500
#   🌐 Best Manifold: torus
#   📈 Complexity: 0.079
#   🔑 Keywords: debug, explain, machine
#   🏷️ Domains: None
#   ⚡ Analysis Time: 0.0036s
#   🎭 GloVe Features:
#     Semantic Coherence: -0.160
#     Embedding Strength: 0.476
#     Math Similarity: 0.111
#     Creative Similarity: 0.221
#   🔄 Method Comparison:
#     Traditional: 0.556
#     Manifold: 0.500
#
# 🎯 Step 2: GloVe Semantic Analysis
#
# 🎭 GloVe Semantic Analysis Demonstration
# ==================================================
# 🔗 Word Similarity Analysis:
#   algorithm    ↔ code        : 0.145
#   story        ↔ narrative   : 0.127
#   equation     ↔ mathematics : 0.000
#   research     ↔ science     : 0.000
#   analyze      ↔ evaluate    : 0.096
#   hello        ↔ greeting    : 0.000
#   function     ↔ method      : -0.051
#   creative     ↔ imagination : 0.319
#
# 🎯 Finding Similar Words:
#   'algorithm' → narrative(0.32), javascript(0.32), database(0.28)
#   'creative' → plot(0.32), imagination(0.32), geometry(0.31)
#   'analyze' → help(0.24), why(0.23), theory(0.19)
#   'equation' → integral(0.28), formula(0.28), variable(0.28)
#   'story' → genre(0.32), for(0.26), metaphor(0.25)
#   'debug' → framework(0.37), programming(0.32), software(0.30)
#
# 🗂️ Semantic Text Clustering Analysis:
#   Semantic Similarity Matrix (top 5 pairs):
#     1. Calculate the derivative of the fun...
#        ↔ Debug the recursive function implem...
#        Similarity: 0.534
#
#     2. Solve the quadratic equation using ...
#        ↔ Calculate the derivative of the fun...
#        Similarity: 0.489
#
#     3. Analyze the causes of climate chang...
#        ↔ Debug the recursive function implem...
#        Similarity: 0.488
#
#     4. Analyze the causes of climate chang...
#        ↔ Evaluate the pros and cons of renew...
#        Similarity: 0.409
#
#     5. Debug the recursive function implem...
#        ↔ Evaluate the pros and cons of renew...
#        Similarity: 0.395
#
# 📊 Task-Domain Semantic Analysis:
#   Mathematical ↔ Creative    : 0.042
#   Mathematical ↔ Programming : -0.022
#   Mathematical ↔ Scientific  : -0.079
#   Creative     ↔ Mathematical: 0.042
#   Creative     ↔ Programming : 0.166
#   Creative     ↔ Scientific  : -0.054
#   Programming  ↔ Mathematical: -0.022
#   Programming  ↔ Creative    : 0.166
#   Programming  ↔ Scientific  : -0.027
#   Scientific   ↔ Mathematical: -0.079
#   Scientific   ↔ Creative    : -0.054
#   Scientific   ↔ Programming : -0.027
#
# 🎯 Step 3: Performance Analysis
#
# 📊 Enhanced Classifier Performance Analysis
# ==================================================
# 📈 Task Distribution:
#   mathematical: 7 (58.3%)
#   creative_writing: 1 (8.3%)
#   reasoning: 1 (8.3%)
#   conversational: 3 (25.0%)
#
# 📊 Classification Statistics:
#   Average Confidence: 0.717 ± 0.180
#   Average Uncertainty: 0.392 ± 0.073
#   Average Complexity: 0.088 ± 0.044
#   Analysis Time Range: 0.0017s - 0.0076s
#
# 🌐 Manifold Usage Distribution:
#   euclidean: 7 (58.3%)
#   sphere: 1 (8.3%)
#   hyperbolic: 1 (8.3%)
#   torus: 3 (25.0%)
#
# 🎭 GloVe Semantic Analysis:
#   Average Semantic Coherence: 0.038 ± 0.130
#   Average Embedding Strength: 0.675 ± 0.126
#   Coherence-Confidence Correlation: 0.855
#
# ⚖️ Method Comparison Analysis:
#   Traditional Average: 0.884
#   Manifold Average: 0.608
#   Manifold Better: 0/12 (0.0%)
#   Traditional Better: 12/12 (100.0%)
#   Tied: 0/12 (0.0%)
#
# 🔍 Classifier Internal Statistics:
#   overall_accuracy: 1.0
#   total_predictions: 35
#   correct_predictions: 35
#   average_performance_score: 1.0
#   manifold_enabled: True
#   cache_size: 12
#   total_history_entries: 35
#   feedback_entries: 35
#
# 🎯 Step 4: Comprehensive Visualization
#
# 📈 Creating Comprehensive Performance Visualizations...
# 📊 Comprehensive visualization saved as 'comprehensive_classifier_analysis.png'
#
# 🎯 Step 5: Online Learning and Adaptation
#
# 🔄 Online Learning and Adaptation Demonstration
# =======================================================
# 📊 Initial Classifier State:
#   Cache Size: 12
#   Training History: 35 predictions
#
# 📚 Processing 5 feedback scenarios...
#
# [1] Scenario: Optimize the machine learning hyperparameters...
#   Predicted: code_generation
#   Actual: mathematical
#   Performance: 0.30
#   Reason: Optimization is more mathematical than coding
#   Correct: ❌
#   Confidence Change: 0.685 → 0.685 (+0.000)
#
# [2] Scenario: Write a compelling character backstory for th...
#   Predicted: creative_writing
#   Actual: creative_writing
#   Performance: 0.95
#   Reason: Perfect classification for creative writing
#   Correct: ✅
#   Confidence Change: 0.759 → 0.759 (+0.000)
#
# [3] Scenario: Analyze the philosophical implications of art...
#   Predicted: reasoning
#   Actual: reasoning
#   Performance: 0.88
#   Reason: Good reasoning task identification
#   Correct: ✅
#   Confidence Change: 0.709 → 0.709 (+0.000)
#
# [4] Scenario: Debug the memory leak in this C++ application...
#   Predicted: scientific
#   Actual: code_generation
#   Performance: 0.25
#   Reason: Debugging is coding, not scientific research
#   Correct: ❌
#   Confidence Change: 0.501 → 0.501 (+0.000)
#
# [5] Scenario: Calculate the statistical significance of the...
#   Predicted: mathematical
#   Actual: scientific
#   Performance: 0.40
#   Reason: Statistical analysis in scientific context
#   Correct: ❌
#   Confidence Change: 0.846 → 0.846 (+0.000)
#
# 📊 Updated Classifier Performance:
#   Overall Accuracy: 92.50%
#   Total Predictions: 40
#   Average Performance Score: 0.945
#   Task-Specific Performance:
#     mathematical   : 83.33% (5/6)
#     creative_writing: 100.00% (6/6)
#     factual_qa     : 100.00% (5/5)
#     reasoning      : 100.00% (6/6)
#     code_generation: 83.33% (5/6)
#     scientific     : 83.33% (5/6)
#     conversational : 100.00% (5/5)
#
# 📈 Learning Progression Analysis:
#   Correct Predictions: 2/5 (40.0%)
#   Average Confidence Change: +0.000
#   Average Score (Correct): 0.915
#   Average Score (Incorrect): 0.317
#
# 🎯 Step 6: Comprehensive Evaluation
#
# 🎯 Comprehensive Classifier Evaluation
# =============================================
# 🔍 Feature Analysis Summary:
#   Traditional Method Average: 0.884
#   Enhanced Method Average: 0.608
#   Performance Improvement: -31.2%
#
# 🎭 GloVe Embeddings Summary:
#   Average Semantic Coherence: 0.038
#   Average Embedding Strength: 0.675
#   Embeddings Used: True
#   Vocabulary Size: 128
#
# 🌐 Manifold Learning Summary:
#   Unique Manifolds Used: 4
#   Most Common Manifold: euclidean
#
# 📊 Performance by Complexity Level:
#   Low    Complexity: Confidence=0.703, Uncertainty=0.412 (4 cases)
#   Medium Complexity: Confidence=0.570, Uncertainty=0.450 (4 cases)
#   High   Complexity: Confidence=0.878, Uncertainty=0.312 (4 cases)
#
# 🎉 Complete Enhanced Classifier Demo Finished!
# =======================================================
# ✅ Demonstrated multi-modal feature fusion (TF-IDF + GloVe)
# ✅ Showed geometric manifold learning integration
# ✅ Analyzed semantic coherence and word relationships
# ✅ Visualized comprehensive performance metrics
# ✅ Demonstrated adaptive online learning
# ✅ Provided interpretable confidence and uncertainty scores
#
# 💡 Key Insights and Recommendations:
#    • Final classification accuracy: 92.50%
#    • Average semantic coherence: 0.038
#    • Average classification confidence: 0.717
#    • Average uncertainty estimate: 0.392
#    • Enhanced method win rate: 0.0%
#    • Multi-modal approach provides richer semantic understanding
#    • Online learning enables continuous improvement
#    • Uncertainty quantification helps identify difficult cases
#    • Geometric manifolds capture task-specific structures
#
# 🔧 Usage Recommendations:
#    • Use GloVe embeddings for semantic similarity tasks
#    • Monitor uncertainty scores for active learning
#    • Apply different manifolds based on task characteristics
#    • Leverage online learning for domain adaptation
#    • Combine traditional and geometric features for robustness

# %%
"""Main demonstration function"""
    
print("🚀 Multi-Model Reward-Guided Inference System")
print("=" * 60)
print("Features demonstrated:")
print("• Automatic model selection based on input analysis")
print("• Task-specific model routing")
print("• Performance monitoring and statistics")
print("• Comprehensive result analysis")
print("=" * 60)

try:
    # Set random seeds for reproducibility
    torch.manual_seed(42)
    np.random.seed(42)
    
    # Run demonstration
    print("\n🎯 Running Multi-Model Inference Demonstration")
    engine, results = demonstrate_multi_model_inference()
    
    # Analyze results
    print("\n📊 Analyzing Results")
    analysis = analyze_results(results)
    
    # Save results
    print("\n💾 Saving Results")
    results_file, summary_file = save_results(engine, results, analysis)
    
    # Final summary
    print("\n🎉 Demonstration Complete!")
    print("=" * 40)
    print(f"✅ Tested {len(engine.models)} specialized models")
    print(f"✅ Evaluated {len(results)} different prompts")
    print(f"✅ Achieved {analysis.get('accuracy', 0):.2%} selection accuracy")
    print(f"✅ Saved comprehensive results")
    
    # Best performing aspects
    model_usage = analysis.get('model_usage', {})
    if model_usage:
        most_used = max(model_usage.keys(), key=lambda k: model_usage[k])
        print(f"\n🏆 Most utilized model: {most_used}")
        usage_count = model_usage[most_used]
        usage_percent = (usage_count / len(results)) * 100
        print(f"   Usage: {usage_count} times ({usage_percent:.1f}%)")
    
    # Recommendations
    print(f"\n💡 System Performance:")
    if analysis.get('accuracy', 0) > 0.8:
        print("   ✅ Excellent model selection accuracy")
    elif analysis.get('accuracy', 0) > 0.6:
        print("   ⚠️ Good model selection, room for improvement")
    else:
        print("   ❌ Model selection needs optimization")
    
    if analysis.get('avg_confidence', 0) > 0.7:
        print("   ✅ High confidence in selections")
    else:
        print("   ⚠️ Consider adjusting selection thresholds")
    
    print(f"\n📁 Files generated:")
    print(f"   • Results: {results_file}")
    print(f"   • Summary: {summary_file}")
    
    
except Exception as e:
    print(f"❌ Demonstration failed: {e}")
    import traceback
    traceback.print_exc()
# Out:
# 🚀 Multi-Model Reward-Guided Inference System
# ============================================================
# Features demonstrated:
# • Automatic model selection based on input analysis
# • Task-specific model routing
# • Performance monitoring and statistics
# • Comprehensive result analysis
# ============================================================
#
# 🎯 Running Multi-Model Inference Demonstration
# 🤖 Multi-Model Inference Demonstration
# ============================================================
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
